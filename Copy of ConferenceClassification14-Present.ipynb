# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Giancarlo\\Desktop\\Intro to Data Science Player Ranks\\Player Ranks No Conferences\\17-18_Player_Stats.csv")

# %%
#CHA with CHO due to Charlotte rename into Hornets.
conditions = [
    (df['Tm'] == 'TOT'), (df['Tm'] == 'PHI'), (df['Tm'] == 'BOS'), (df['Tm'] == 'NYK'), (df['Tm'] == 'BUF'), 
    (df['Tm'] == 'NYN'), (df['Tm'] == 'MIL'), (df['Tm'] == 'WAS'), (df['Tm'] == 'CHI'), (df['Tm'] == 'CLE'), 
    (df['Tm'] == 'IND'), (df['Tm'] == 'ATL'), (df['Tm'] == 'BRK'), (df['Tm'] == 'DET'), (df['Tm'] == 'MIA'),
    (df['Tm'] == 'CHO'), (df['Tm'] == 'ORL'), (df['Tm'] == 'TOR')]

choices = ['NaN', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East', 'East',
          'East', 'East', 'East', 'East', 'East']

# %%
df['Conference'] = np.select(conditions, choices, default = 'West')

# %%
df
# Out:
#       Rk                           Player Pos  Age   Tm   G  GS    MP   FG  \
# 0      1           Alex Abrines\abrinal01  SG   24  OKC  75   8  1134  115
# 1      2               Quincy Acy\acyqu01  PF   27  BRK  70   8  1359  130
# 2      3           Steven Adams\adamsst01   C   24  OKC  76  76  2487  448
# 3      4            Bam Adebayo\adebaba01   C   20  MIA  69  19  1368  174
# 4      5          Arron Afflalo\afflaar01  SG   32  ORL  53   3   682   65
# 5      6           Cole Aldrich\aldrico01   C   29  MIN  21   0    49    5
# 6      7      LaMarcus Aldridge\aldrila01   C   32  SAS  75  75  2509  687
# 7      8          Jarrett Allen\allenja01   C   19  BRK  72  31  1441  234
# 8      9           Kadeem Allen\allenka01  PG   25  BOS  18   1   107    6
# 9     10             Tony Allen\allento01  SF   36  NOP  22   0   273   44
# 10    11        Al-Farouq Aminu\aminual01  PF   27  POR  69  67  2072  230
# 11    12        Justin Anderson\anderju01  SF   24  PHI  38   0   519   87
# 12    13          Kyle Anderson\anderky01  SF   24  SAS  74  67  1978  231
# 13    14          Ryan Anderson\anderry01  PF   29  HOU  66  50  1725  207
# 14    15           Ike Anigbogu\anigbik01   C   19  IND  11   0    30    4
# 15    16  Giannis Antetokounmpo\antetgi01  PF   23  MIL  75  75  2756  742
# 16    17        Carmelo Anthony\anthoca01  PF   33  OKC  78  78  2501  472
# 17    18             OG Anunoby\anunoog01  SF   20  TOR  74  62  1481  163
# 18    19       Ryan Arcidiacono\arcidry01  PG   23  CHI  24   0   304   17
# 19    20           Trevor Ariza\arizatr01  SF   32  HOU  67  67  2269  268
# 20    21         Darrell Arthur\arthuda01  PF   29  DEN  19   1   141   22
# 21    22            Jamel Artis\artisja01  SG   25  ORL  15   1   279   31
# 22    23               Omer Asik\asikom01   C   31  TOT  18   0   182    9
# 23    23               Omer Asik\asikom01   C   31  NOP  14   0   121    7
# 24    23               Omer Asik\asikom01   C   31  CHI   4   0    61    2
# 25    24          D.J. Augustin\augusdj01  PG   30  ORL  75  36  1760  244
# 26    25           Luke Babbitt\babbilu01  SF   28  TOT  50  14   715   91
# 27    25           Luke Babbitt\babbilu01  SF   28  ATL  37   9   570   80
# 28    25           Luke Babbitt\babbilu01  SF   28  MIA  13   5   145   11
# 29    26           Dwayne Bacon\bacondw01  SG   22  CHO  53   6   713   72
# ..   ...                              ...  ..  ...  ...  ..  ..   ...  ...
# 634  517          Alan Williams\willial03  PF   25  PHO   5   0    70    7
# 635  518          C.J. Williams\willicj01  SG   27  LAC  38  17   707   87
# 636  519       Derrick Williams\willide02  PF   26  LAL   2   0     9    1
# 637  520           Lou Williams\willilo02  SG   31  LAC  79  19  2589  582
# 638  521        Marvin Williams\willima02  PF   31  CHO  78  78  2006  258
# 639  522          Matt Williams\willima05  SG   24  MIA   3   0    11    2
# 640  523          Troy Williams\willitr02  SF   23  TOT  21   1   307   51
# 641  523          Troy Williams\willitr02  SF   23  HOU   4   0    17    2
# 642  523          Troy Williams\willitr02  SF   23  NYK  17   1   290   49
# 643  524            D.J. Wilson\wilsodj01  PF   21  MIL  22   0    71    9
# 644  525           Jamil Wilson\wilsoja02  SF   27  LAC  15  10   274   38
# 645  526        Justise Winslow\winslju01  PF   21  MIA  68  25  1680  207
# 646  527            Jeff Withey\witheje01   C   27  DAL   9   0    39    6
# 647  528           Nate Wolters\woltena01  PG   26  UTA   5   0    19    1
# 648  529         Brandan Wright\wrighbr03  PF   30  TOT  28   1   381   59
# 649  529         Brandan Wright\wrighbr03  PF   30  MEM  27   1   366   57
# 650  529         Brandan Wright\wrighbr03  PF   30  HOU   1   0    15    2
# 651  530           Delon Wright\wrighde01  PG   25  TOR  69   4  1433  201
# 652  531     Guerschon Yabusele\yabusgu01  PF   22  BOS  33   4   235   26
# 653  532            James Young\youngja01  SG   22  PHI   6   0    61    5
# 654  533              Joe Young\youngjo01  PG   25  IND  53   1   558   80
# 655  534             Nick Young\youngni01  SG   32  GSW  80   8  1393  201
# 656  535         Thaddeus Young\youngth01  PF   29  IND  81  81  2607  421
# 657  536            Cody Zeller\zelleco01   C   25  CHO  33   0   627   85
# 658  537           Tyler Zeller\zellety01   C   28  TOT  66  34  1109  187
# 659  537           Tyler Zeller\zellety01   C   28  BRK  42  33   703  125
# 660  537           Tyler Zeller\zellety01   C   28  MIL  24   1   406   62
# 661  538            Paul Zipser\zipsepa01  SF   23  CHI  54  12   824   81
# 662  539             Ante Zizic\zizican01   C   21  CLE  32   2   214   49
# 663  540            Ivica Zubac\zubaciv01   C   20  LAL  43   0   410   61
#
#       FGA     ...      ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS  \
# 0     291     ...       26   88  114   28   38    8   25  124   353
# 1     365     ...       40  217  257   57   33   29   60  149   411
# 2     712     ...      384  301  685   88   92   78  128  215  1056
# 3     340     ...      118  263  381  101   32   41   66  138   477
# 4     162     ...        4   62   66   30    4    9   21   56   179
# 5      15     ...        3   12   15    3    2    1    1   11    12
# 6    1347     ...      246  389  635  152   43   90  111  161  1735
# 7     397     ...      144  244  388   49   28   88   82  147   587
# 8      22     ...        4    7   11   12    3    2    9   15    19
# 9      91     ...       20   27   47    9   11    3   19   49   103
# 10    582     ...       97  428  525   84   79   40   79  136   644
# 11    202     ...       25   68   93   25   15    7   16   54   236
# 12    438     ...       84  312  396  202  115   60   94  114   585
# 13    480     ...       94  237  331   60   24   21   42  126   617
# 14      9     ...        5    4    9    0    1    3    2    1    13
# 15   1402     ...      156  597  753  361  109  106  223  231  2014
# 16   1168     ...       67  386  453  103   47   49   99  197  1261
# 17    346     ...       44  140  184   55   52   14   45  130   438
# 18     41     ...        1   24   25   35   13    0   13   18    48
# 19    651     ...       33  261  294  105   98   13   52  132   782
# 20     47     ...        3   12   15    9    8    3   15   22    54
# 21     79     ...        4   34   38   18    2    3    8   11    77
# 22     22     ...        9   38   47    3    2    4    9   20    22
# 23     16     ...        7   30   37    2    1    2    5   14    18
# 24      6     ...        2    8   10    1    1    2    4    6     4
# 25    540     ...       30  130  160  287   54    0  123   94   766
# 26    215     ...        7   89   96   31    8    7   19   54   259
# 27    168     ...        5   76   81   26    7    5   15   47   226
# 28     47     ...        2   13   15    5    1    2    4    7    33
# 29    192     ...        4  120  124   38   16    2   23   46   175
# ..    ...     ...      ...  ...  ...  ...  ...  ...  ...  ...   ...
# 634    18     ...        3   19   22    8    5    1    7   13    20
# 635   197     ...       12   44   56   43   31   13   20   63   209
# 636     4     ...        0    1    1    0    0    0    0    0     2
# 637  1337     ...       40  158  198  417   85   19  234  106  1782
# 638   563     ...       74  296  370   96   56   38   66  116   744
# 639     6     ...        0    1    1    0    0    0    1    1     5
# 640   109     ...       22   41   63   16   20    4   19   34   133
# 641     9     ...        1    3    4    1    1    0    1    2     5
# 642   100     ...       21   38   59   15   19    4   18   32   128
# 643    16     ...        2    8   10    3    3    1    4    7    21
# 644    81     ...        3   29   32   10    5    8    8   34   105
# 645   488     ...       64  306  370  148   54   33   77  140   529
# 646    16     ...        1    9   10    0    0    3    2    3    15
# 647     6     ...        1    1    2    1    0    0    0    1     2
# 648   102     ...       33   62   95   13   13   26    8   32   139
# 649    99     ...       32   61   93   13   13   25    8   29   135
# 650     3     ...        1    1    2    0    0    1    0    3     4
# 651   432     ...       45  153  198  200   72   33   78   81   555
# 652    61     ...       17   35   52   16    4    5   12   23    79
# 653    14     ...        0    2    2    2    0    0    1    4    17
# 654   186     ...       12   51   63   39   14    1   26   39   207
# 655   488     ...       20  105  125   36   38    7   39  100   581
# 656   864     ...      184  328  512  152  135   36  105  175   955
# 657   156     ...       67  110  177   31   14   21   33   81   233
# 658   334     ...      110  195  305   47   15   35   47  126   441
# 659   229     ...       63  131  194   28    8   21   35   78   300
# 660   105     ...       47   64  111   19    7   14   12   48   141
# 661   234     ...       13  118  131   46   20   15   43   86   218
# 662    67     ...       24   36   60    5    2   13   11   30   119
# 663   122     ...       45   78  123   25    8   15   26   47   161
#
#      Conference
# 0          West
# 1          East
# 2          West
# 3          East
# 4          East
# 5          West
# 6          West
# 7          East
# 8          East
# 9          West
# 10         West
# 11         East
# 12         West
# 13         West
# 14         East
# 15         East
# 16         West
# 17         East
# 18         East
# 19         West
# 20         West
# 21         East
# 22          NaN
# 23         West
# 24         East
# 25         East
# 26          NaN
# 27         East
# 28         East
# 29         East
# ..          ...
# 634        West
# 635        West
# 636        West
# 637        West
# 638        East
# 639        East
# 640         NaN
# 641        West
# 642        East
# 643        East
# 644        West
# 645        East
# 646        West
# 647        West
# 648         NaN
# 649        West
# 650        West
# 651        East
# 652        East
# 653        East
# 654        East
# 655        West
# 656        East
# 657        East
# 658         NaN
# 659        East
# 660        East
# 661        East
# 662        East
# 663        West
#
# [664 rows x 31 columns]

# %%
df.to_csv('C:\\Users\\Giancarlo\\Desktop\\Intro to Data Science Player Ranks\\Player Ranks with Conferences\\17-18_Player_Conferences.csv', index = False)
